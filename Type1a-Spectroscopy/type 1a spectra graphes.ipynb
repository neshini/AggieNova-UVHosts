# %% [markdown]
# # To do
# - add extinction level

# %%
#L=F*D^2
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors

# %%
# SN2011by, NGC3972
#distance in cm
d_a=6.05893E+25
file_a = 'SN2011by_110509_uvopt_obswave_obsflux.dat'
f_a= pd.read_csv(file_a, sep='\s+')

#used to index row,column; part of pandas
flux_a = f_a.iloc[:, 1]
wave_a = f_a.iloc[:,0]

lum_a = flux_a*(d_a**2)
wave_a
# Out:
# 0       1700.4548
# 1       1701.9991
# 2       1703.5435
# 3       1705.0878
# 4       1706.6322
#           ...
# 1757    5590.7407
# 1758    5593.4765
# 1759    5596.2124
# 1760    5598.9482
# 1761    8000.0000
# Name: wavelength, Length: 1762, dtype: float64

# %%
# SN2011iv, NGC1404
d_b=6.02554E+25
file_b = 'SN2011iv_111211_full.dat'
f_b= pd.read_csv(file_b, sep='\s+')

flux_b = f_b.iloc[:, 1]
wave_b = f_b.iloc[:,0]

lum_b = flux_b*(d_b**2)
wave_b
# Out:
# 0        1701.1529
# 1        1702.6971
# 2        1704.2414
# 3        1705.7856
# 4        1707.3299
#            ...
# 2642     9982.4176
# 2643     9987.2773
# 2644     9992.1370
# 2645     9996.9966
# 2646    10001.8560
# Name: wavelength, Length: 2647, dtype: float64

# %%
# SN2011fe, M101
d_c=2.1291E+25
file_c = 'SN2011fe_110907_uvopt_obswave_obsflux.dat'
f_c= pd.read_csv(file_c, sep='\s+', nrows= 2553)

flux_c = f_c.iloc[:, 1]
wave_c = f_c.iloc[:,0]

lum_c = flux_c*(d_c**2)
wave_c
# Out:
# 0       1780.4000
# 1       1781.8000
# 2       1783.2000
# 3       1784.6000
# 4       1786.0000
#           ...
# 2548    9980.1999
# 2549    9985.0999
# 2550    9989.9999
# 2551    9994.8999
# 2552    9999.7999
# Name: wavelength, Length: 2553, dtype: float64

# %%
# SN2016ccj, NGC4125
d_d=5.33878E+26
file_d = 'SN2016ccj_160514_uvopt_obswave_obsflux.dat'
f_d= pd.read_csv(file_d, sep='\s+', nrows=450)

flux_d = f_d.iloc[:, 1]
wave_d = f_d.iloc[:,0]

lum_d = flux_d*(d_d**2)
wave_d
# Out:
# 0       1020.0
# 1       1040.0
# 2       1060.0
# 3       1080.0
# 4       1100.0
#         ...
# 445     9920.0
# 446     9940.0
# 447     9960.0
# 448     9980.0
# 449    10000.0
# Name: wavelength, Length: 450, dtype: float64

# %%
# SN2017erp, 
d_e=8.62573E+25
file_e = 'SN2017erp_170702_uvopt_obswave_obsflux.dat'
f_e= pd.read_csv(file_e, sep='\s+', nrows=450)

flux_e = f_e.iloc[:, 1]
wave_e = f_e.iloc[:,0]

lum_e = flux_e*(d_e**2)
wave_e
# Out:
# 0      1600.0
# 1      1610.0
# 2      1625.0
# 3      1630.0
# 4      1635.0
#         ...
# 445    3925.0
# 446    3930.0
# 447    3935.0
# 448    3940.0
# 449    3945.0
# Name: wavelength, Length: 450, dtype: float64

# %% [markdown]
# new data

# %%
# SN1992A, 
d_f=6.05893E+25
file_f = 'SN1992A_HST.dat'
f_f= pd.read_csv(file_f, sep='\s+')

flux_f = f_f.iloc[:, 1]
wave_f = f_f.iloc[:,0]

lum_f = flux_f*(d_f**2)
wave_f
# Out:
# 0        1448.26
# 1        1448.76
# 2        1449.28
# 3        1449.78
# 4        1450.29
#           ...
# 13040    8070.39
# 13041    8070.90
# 13042    8071.40
# 13043    8071.91
# 13044    8072.43
# Name: 1447.7600, Length: 13045, dtype: float64

# %%
# SN1981B, 
d_g=4.54E+25
file_g = 'SN1981B.dat'
f_g= pd.read_csv(file_g, sep='\s+')

flux_g = f_g.iloc[:, 1]
wave_g = f_g.iloc[:,0]

lum_g = flux_g*(d_g**2)
wave_g
# Out:
# 0       3082.355
# 1       3083.110
# 2       3083.865
# 3       3084.620
# 4       3085.375
#           ...
# 7026    8386.985
# 7027    8387.740
# 7028    8388.495
# 7029    8389.250
# 7030    8390.005
# Name: 3081.6, Length: 7031, dtype: float64

# %%
# SN2012cg, 
d_h=4.58E+25
file_h = 'SN2012cg_hst_20120604.csv'
f_h= pd.read_csv(file_h, delimiter=',')

flux_h = f_h.iloc[:, 2]
wave_h = f_h.iloc[:,1]

lum_h= flux_h*(d_h**2)
wave_h
# Out:
# 0       1665.08
# 1       1666.45
# 2       1667.82
# 3       1669.19
# 4       1670.57
#          ...
# 1951    5686.68
# 1952    5689.41
# 1953    5692.15
# 1954    5694.88
# 1955    5697.62
# Name: 1663.71, Length: 1956, dtype: float64

# %%
# SN2013dy, 
d_i=6.53E+25
file_i = 'sn2013dy-visit3-hst.flm'
f_i= pd.read_csv(file_i, sep='\s+')

flux_i = f_i.iloc[:, 1]
wave_i = f_i.iloc[:,0]

lum_i = flux_i*(d_i**2)
wave_i
# Out:
# 0        1622.5
# 1        1624.0
# 2        1625.5
# 3        1627.0
# 4        1628.5
#          ...
# 5733    10222.0
# 5734    10223.5
# 5735    10225.0
# 5736    10226.5
# 5737    10228.0
# Name: 1621.00, Length: 5738, dtype: float64

# %%
# SN2015f 
d_j=6.04E+25
file_j = 'SN2015F_full_20150326.csv'
f_j= pd.read_csv(file_j, delimiter=',')

flux_j = f_j.iloc[:, 2]
wave_j = f_j.iloc[:,1]

lum_j = flux_j*(d_j**2)
wave_j
# Out:
# 0        1652.96
# 1        1654.51
# 2        1656.05
# 3        1657.59
# 4        1659.14
#           ...
# 2746    10214.30
# 2747    10219.16
# 2748    10224.01
# 2749    10228.87
# 2750    10233.73
# Name: 1651.42, Length: 2751, dtype: float64

# %%
#wave x, flux y
plt.figure()
plt.xlabel('Wavelength (A)')
plt.ylabel('Flux Density (erg/s/cm^2)')
plt.plot(wave_a, flux_a, label='SN2011by', color='C0')
plt.plot(wave_b, flux_b, label='SN2011iv', color='C1')
plt.plot(wave_d, flux_d, label='SN2016ccj', color='C3')
plt.plot(wave_e, flux_e, label='SN2017erp', color='C4')
plt.title(" Wavelength vs Flux Density")
plt.legend()
plt.savefig('wavevflux(4)')
plt.show()
plt.close()


plt.figure()
plt.xlabel('Wavelength (A)')
plt.ylabel('Flux Density (erg/s/cm^2)')
plt.plot(wave_a, lum_a, label='SN2011by', color='C0')
plt.plot(wave_b, lum_b, label='SN2011iv', color='C1')
plt.plot(wave_c, lum_c, label='SN2011fe', color='C2')
plt.plot(wave_d, lum_d, label='SN2016ccj', color='C3')
plt.plot(wave_e, lum_e, label='SN2017erp', color='C4')
plt.plot(wave_f, lum_f, label='SN1992a', color='C5')
plt.plot(wave_g, lum_g, label='SN1981b', color='C6')
plt.plot(wave_h, lum_h, label='SN2012cg', color='C7')
plt.plot(wave_i, lum_i, label='SN2013dy', color='C8')
plt.plot(wave_j, lum_j, label='SN2015f', color='C9')
plt.title(" Wavelength vs Flux Density")
plt.legend()
plt.savefig('wavevflux(5)')
plt.show()
plt.close()

# %%
#wave x, flux y
plt.figure()
plt.xlabel('Wavelength (A)')
plt.ylabel('Flux Density (erg/s/cm^2)')
plt.yscale("log")
plt.plot(wave_a, flux_a, label='SN2011by', color='C0')
plt.plot(wave_b, flux_b, label='SN2011iv', color='C1')
plt.plot(wave_d, flux_d, label='SN2016ccj', color='C3')
plt.plot(wave_e, flux_e, label='SN2017erp', color='C4')
plt.title(" Wavelength vs Flux Density")
plt.legend()
plt.savefig('wavevflux(4)')
plt.show()
plt.close()

plt.figure()
plt.xlabel('Wavelength (A)')
plt.ylabel('Flux Density (erg/s/cm^2)')
plt.yscale("log")
plt.plot(wave_a, flux_a, label='SN2011by', color='C0')
plt.plot(wave_b, flux_b, label='SN2011iv', color='C1')
plt.plot(wave_c, flux_c, label='SN2011fe', color='C2')
plt.plot(wave_d, flux_d, label='SN2016ccj', color='C3')
plt.plot(wave_e, flux_e, label='SN2017erp', color='C4')
plt.title(" Wavelength vs Flux Density")
plt.legend()
plt.savefig('wavevflux(5)')
plt.show()
plt.close()

# %%
plt.figure()
plt.xlabel('Wavelength (A)')
plt.ylabel('Flux Density (erg/s/cm^2)')
plt.yscale("log")
plt.plot(wave_a, lum_a, label='SN2011by', color='C0')
plt.plot(wave_b, lum_b, label='SN2011iv', color='C1')
plt.plot(wave_c, lum_c, label='SN2011fe', color='C2')
plt.plot(wave_d, lum_d, label='SN2016ccj', color='C3')
plt.plot(wave_e, lum_e, label='SN2017erp', color='C4')
plt.plot(wave_f, lum_f, label='SN1992a', color='C5')
plt.plot(wave_g, lum_g, label='SN1981b', color='C6')
plt.plot(wave_h, lum_h, label='SN2012cg', color='C7')
plt.plot(wave_i, lum_i, label='SN2013dy', color='C8')
plt.plot(wave_j, lum_j, label='SN2015f', color='C9')
plt.title(" Wavelength vs Flux Density")
plt.legend()
plt.savefig('wavevflux(10)')
plt.show()
plt.close()

# %%
plt.figure()
plt.xlabel('Wavelength (A)')
plt.ylabel('Flux Density (erg/s/cm^2)')
plt.yscale("log")
plt.plot(wave_a, lum_a, label='SN2011by', color='C0')
plt.plot(wave_b, lum_b, label='SN2011iv', color='C1')
plt.plot(wave_c, lum_c, label='SN2011fe', color='C2')
plt.plot(wave_d, lum_d, label='SN2016ccj', color='C3')
plt.plot(wave_e, lum_e, label='SN2017erp', color='C4')
plt.plot(wave_f, lum_f, label='SN1992a', color='C5')
#plt.plot(wave_g, flux_g, label='SN1981b', color='C6')
plt.plot(wave_h, lum_h, label='SN2012cg', color='C7')
plt.plot(wave_i, lum_i, label='SN2013dy', color='C8')
plt.plot(wave_j, lum_j, label='SN2015f', color='C9')
plt.title(" Wavelength vs Luminosity")
plt.legend()
plt.savefig('wavevflux(10)')
plt.show()
plt.close()

# %%
#wave x, lum y

plt.figure()
plt.xlabel('Wavelength (A)')
plt.ylabel('Luminosity (erg/s/Angstrom)')
#to change y axis to log
plt.yscale("log")
plt.plot(wave_a, lum_a, label='SN2011by', color='C0')
plt.plot(wave_b, lum_b, label='SN2011iv', color='C1')
plt.plot(wave_c, lum_c, label='SN2011fe', color='C2')
plt.plot(wave_d, lum_d, label='SN2016ccj', color='C3')
plt.plot(wave_e, lum_e, label='SN2017erp', color='C4')
plt.plot(wave_f, lum_f, label='SN1992a', color='C5')
plt.plot(wave_g, lum_g, label='SN1981b', color='C6')
plt.plot(wave_h, lum_h, label='SN2012cg', color='C7')
plt.plot(wave_i, lum_i, label='SN2013dy', color='C8')
plt.plot(wave_j, lum_j, label='SN2015f', color='C9')
plt.title(" Wavelength vs Luminosity")
plt.legend()
plt.savefig('wavevlum(5)')
plt.show()
plt.close()

# %%
#looking at SN2012cg - in black 

plt.figure()
plt.xlabel('Wavelength (A)')
plt.ylabel('Luminosity (erg/s/Angstrom)')
#to change y axis to log
plt.yscale("log")
plt.plot(wave_a, lum_a, label='SN2011by', color='C0')
#plt.plot(wave_b, lum_b, label='SN2011iv', color='C1')
plt.plot(wave_c, lum_c, label='SN2011fe', color='C2')
#plt.plot(wave_d, lum_d, label='SN2016ccj', color='C3')
plt.plot(wave_e, lum_e, label='SN2017erp', color='C4')
#plt.plot(wave_f, lum_f, label='SN1992a', color='C5')
#plt.plot(wave_g, lum_g, label='SN1981b', color='C6')
plt.plot(wave_h, lum_h, label='SN2012cg', color='k')
plt.plot(wave_i, lum_i, label='SN2013dy', color='C8')
plt.plot(wave_j, lum_j, label='SN2015f', color='C9')
plt.title(" Wavelength vs Luminosity")
plt.legend()
plt.savefig('wavevlum(5)')
plt.show()
plt.close()

# %%
#just 2012cg

plt.figure()
plt.xlabel('Wavelength (A)')
plt.ylabel('Luminosity (erg/s/Angstrom)')
plt.yscale("log")
plt.plot(wave_h, lum_h, label='SN2012cg', color='k')
#corrected 12cg - red
plt.plot(wave, lum_hc, label='SN2012cg(w/ex)', color='r')
plt.title(" Wavelength vs Luminosity")
plt.legend()
plt.savefig('w)')
plt.show()
plt.close()

# %%
import extinction

# %%
# defining the values for wave and flux in the function

file = 'SN2012cg_hst_20120604.dat'
data= pd.read_csv(file, sep='\s+')
data.columns= ['SN_Wavelength','SN_Flux']

wave = data['SN_Wavelength'].values
flux = data['SN_Flux'].values

wave= wave.astype('double')
flux= flux.astype('double')

rv = 3.1
ebv = -.1
av = rv * ebv
mwf = extinction.apply(extinction.ccm89(wave, av, rv), flux)
mwf

#plot wavelength and mwf
lum_hc= mwf*(d_h**2)


plt.figure()
plt.xlabel('Wavelength (A)')
plt.ylabel('Luminosity (erg/s/Angstrom)')
plt.yscale("log")
plt.plot(wave_a, lum_a, label='SN2011by', color='C5')
plt.plot(wave_b, lum_b, label='SN2011iv', color='C6')
plt.plot(wave_c, lum_c, label='SN2011fe', color='C7')
plt.plot(wave_d, lum_d, label='SN2016ccj', color='C8')
plt.plot(wave_e, lum_e, label='SN2017erp', color='C9')
plt.plot(wave_f, lum_f, label='SN1992a', color='C0')
#plt.plot(wave_g, lum_g, label='SN1981b', color='C1')

#normal 12cg - black
#plt.plot(wave_h, lum_h, label='SN2012cg', color='k')
#corrected 12cg - red
plt.plot(wave, lum_hc, label='SN2012cg(w/ex)', color='r')

plt.plot(wave_i, lum_i, label='SN2013dy', color='C3')
plt.plot(wave_j, lum_j, label='SN2015f', color='C4')
plt.title(" Wavelength vs Luminosity")
plt.legend()
plt.savefig('wy')
plt.show()
plt.close()
