# %% [markdown]
# # Instructions
# 1. So you will read in the photometry for a galaxy,
# 2. pull the spectrum from Blast,
# 3. compute the k correction,
# 4. and add (or subtract depending on convention) to the photometry
#
# ### goal : to make corrected photometry.

# %%
#remake those og graphes with the corrected fluxes

# %%
import numpy as np
import pandas as pd
import  matplotlib.pyplot as plt
import math
from urllib.request import urlopen
import json

# %%
#doing an example of opening + finding relevant data

# %%
def safe_get(data, key, default=None):
    return data.get(key, default)

# %%
#step 2- going to assume im getting model spectrum, ie SED

#nvm it looks like : https://blast.scimma.org/download_modelfit/SN2017erp/global
# with the URL path `<base_blast_url>/download_modelfit/<transient_name>/<aperture_type>`
#model downloaded in units of maggies - YAY

SNList = ['SN2017erp']

for name in SNList:
    url = f"https://blast.scimma.org/download_modelfit/{name}/global"
    response = urlopen(url)
    
    #saving it
    folder = 'model_datas'
    filename = f"{folder}/{name}_global_modeldata.npz"
    with open(filename, "wb") as f:
        f.write(response.read())
    #opens a file, writes in binary (wb)

# %%
data = np.load('model_datas/SN2017erp_global_modeldata.npz')
#gives keys lipe 'phot' 
print(data.files)

wave = data['rest_wavelength']
flux = data['spec']
#for error
spec_84 = data['spec_84']
spec_16 = data['spec_16']
# Out:
# ['rest_wavelength', 'spec', 'phot', 'spec_16', 'spec_84', 'phot_16', 'phot_84']

# %% [markdown]
# #### step 3 overview: k correction
#
# To account for the stretching of the wavelength at a hypothetical z value, I multiplied all my wavelengths by (1+z).
#
# To account for the stretching of the space, I divided all my flux by (1+z).
#
# To account for time dilation, I multiplied my epochs by (1+z).

# %% [markdown]
# Filter	Central Wavelength (Å)
# - v	5468
# - b	4392
# - u	3465
# - uvw1	2600
# - uvm2	2246
# - uvw2	1928

# %%
#functions needed
def specin_countsout(wavez,fluxz):

    h = 6.6260755e-27
    c = 2.99792458e18
    hc = h*c

    files = ['UVW2_2010.txt','UVM2_2010.txt','UVW1_2010.txt','U_UVOT.txt','B_UVOT.txt', 'V_UVOT.txt']
    filtercurves = ['UVW2','UVM2','UVW1','U','B','V'] ### STRING LIST
    zeropoints = [17.38, 16.85, 17.44, 18.34, 19.11, 17.89] ### PHOTOMETRIC ZEROPOINTS BASED ON VEGA
    filtereffwavelength=[2030,2231,2634,3501,4329,5402] ### EFFECTIVE VEGA WAVELENGTH FOR EACH FILTER (IN SAME ORDER)
    mag_array = np.zeros(len(filtercurves))
    counts_array = np.zeros(len(filtercurves))

    for x in range(len(filtercurves)):
        filter_wave,filter_ea = np.loadtxt("UVOTfilters_Breeveld2011/"+files[x],dtype=float,usecols=(0,1),unpack=True)
        sp_ea = np.interp(wavez,filter_wave,filter_ea) ### spectrum effective area
        counts_array[x] = np.trapz(sp_ea*fluxz*wavez/hc,wavez) ### Integrating under the curve using numpy
        mag_array[x] = -2.5*np.log10(counts_array[x])+zeropoints[x] ### Calculated magnitudes

    return counts_array, mag_array

def safe_get(data, key, default=None):
    return data.get(key, default)

filter_lambdas = {
    'UVW2': 1928,
    'UVM2': 2246,
    'UVW1': 2600,
    'U':    3465,
    'B':    4392,
    'V':    5468
}

# %%
#wait..
#combine everything into one huge large doc

#og phot data
og_df = pd.read_csv('~/Desktop/aggie nova/galaxy project/eazy-photoz/FinalPhotUV.dat', sep  ='\s+')
og_df.set_index('sn', inplace=True)

#final data setup
filter_names = ['UVW2','UVM2','UVW1','U','B','V']
columns = ['sn','K_UVW2','Kerr_UVW2','K_UVM2','Kerr_UVM2','K_UVW1','Kerr_UVW1','K_U','Kerr_U','K_B','Kerr_B','K_V','Kerr_V']
final_rows = []

#MAIN LOOP!!!
for name in og_df.index:
    #print(name)
    
    try:
        #getting model fit sed from blast
        url = f"https://blast.scimma.org/download_modelfit/{name}/global"
        response = urlopen(url)

        #saving it
        folder = 'model_datas'
        filename = f"{folder}/{name}_global_modeldata.npz"
        with open(filename, "wb") as f:
            f.write(response.read())

        data = np.load(f'model_datas/{name}_global_modeldata.npz')
        
        #gathering relevant data
        wave = data['rest_wavelength']
        flux = data['spec']
        spec_84 = data['spec_84']
        spec_16 = data['spec_16']

        # to find z + reshifted sed from blast
        response = urlopen(f"https://blast.scimma.org/api/transient/get/{name}?format=json")
        info = json.loads(response.read())

        z = safe_get(info, "host_redshift")
        wave_z = wave * (1+z)
        flux_z = flux / (1+z)

        #kcorrections part
        counts, mags = specin_countsout(wave,flux)
        zcounts, zmags = specin_countsout(wave_z,flux_z)

        K_vals = zmags - mags

        ##########
        #for error -tbd
        
        counts_84, mags_84 = specin_countsout(wave,spec_84)
        counts_16, mags_16 = specin_countsout(wave,spec_16)
        
        zcounts_84, zmags_84 = specin_countsout(wave_z,spec_84 / (1+z))
        zcounts_16, zmags_16 = specin_countsout(wave_z,spec_16 / (1+z))
        
        K_84 = zmags_84 - mags_84
        K_16 = zmags_16 - mags_16

        K_err = 0.5 * np.abs(K_84 - K_16)
        ##########
        

        #creating rows of final data
        row = {'sn': name}
        for i, filt in enumerate(filter_names):
            m_obs = og_df.loc[name, filt]           # observed mag
            row[f'K_{filt}'] = m_obs - K_vals[i]    # K-correction value for this filter
            row[f'Kerr_{filt}'] = K_err[i]          # K-errs for this filter

        #adding em  
        final_rows.append(row)
        
    except Exception as e:
        print(f"{name}: model unavailable — {e}")
        row = {'sn': name}
        for filt in filter_lambdas:
            row[f'K_{filt}'] = np.nan
            row[f'Kerr_{filt}'] = np.nan
        #adding em  
        final_rows.append(row)    

#saving df        
final_df = pd.DataFrame(final_rows, columns=columns)
final_df.to_csv('KcorrectedFinalPhotUV.csv', index=False)
print(final_df.head())
print(final_df.shape)
# Out:
# SN2016eii: model unavailable — HTTP Error 404: Not Found
# SN2010ev: model unavailable — HTTP Error 404: Not Found
# SN2007bm: model unavailable — HTTP Error 404: Not Found
# SN2012cp: model unavailable — HTTP Error 404: Not Found
# SN2010ih: model unavailable — HTTP Error 404: Not Found
# PS1-14xw: model unavailable — unsupported operand type(s) for +: 'int' and 'NoneType'
# SN2012fr: model unavailable — HTTP Error 404: Not Found
# SN2014J: model unavailable — HTTP Error 404: Not Found
# SN2011de: model unavailable — unsupported operand type(s) for +: 'int' and 'NoneType'
# SN2011at: model unavailable — HTTP Error 404: Not Found
# SN2011dm: model unavailable — HTTP Error 404: Not Found
# SN2013gh: model unavailable — HTTP Error 404: Not Found
# SN2013cs: model unavailable — HTTP Error 404: Not Found
# SN2008ha: model unavailable — unsupported operand type(s) for +: 'int' and 'NoneType'
# SN2008Q: model unavailable — HTTP Error 404: Not Found
# ASASSN-14lw: model unavailable — HTTP Error 404: Not Found
# SN2013cg: model unavailable — HTTP Error 404: Not Found
# SN2016blc: model unavailable — HTTP Error 404: Not Found
# SN2009ig: model unavailable — HTTP Error 404: Not Found
# SN2016F: model unavailable — unsupported operand type(s) for +: 'int' and 'NoneType'
# SN2015I: model unavailable — HTTP Error 404: Not Found
# SN2016cnx: model unavailable — HTTP Error 404: Not Found
# SN2012ht: model unavailable — unsupported operand type(s) for +: 'int' and 'NoneType'
# SN2016ccz: model unavailable — HTTP Error 404: Not Found
# SN2016eiy: model unavailable — HTTP Error 404: Not Found
# SN2005am: model unavailable — HTTP Error 404: Not Found
# ASASSN-15od: model unavailable — unsupported operand type(s) for +: 'int' and 'NoneType'
# SN2016daj: model unavailable — unsupported operand type(s) for +: 'int' and 'NoneType'
# SN2013hn: model unavailable — HTTP Error 404: Not Found
# SN2007sr: model unavailable — HTTP Error 404: Not Found
# SN2013aa: model unavailable — HTTP Error 404: Not Found
# SNF20080514002: model unavailable — HTTP Error 404: Not Found
# SN2015ak: model unavailable — HTTP Error 404: Not Found
# ASASSN-15aj: model unavailable — HTTP Error 404: Not Found
# SN2014ai: model unavailable — unsupported operand type(s) for +: 'int' and 'NoneType'
# SN2005cf: model unavailable — HTTP Error 404: Not Found
# SN2007cv: model unavailable — HTTP Error 404: Not Found
# ASASSN-15hx: model unavailable — HTTP Error 404: Not Found
# SN2010kg: model unavailable — HTTP Error 404: Not Found
#             sn     K_UVW2     Kerr_UVW2     K_UVM2  Kerr_UVM2     K_UVW1  \
# 0    SN2016eii        NaN           NaN        NaN        NaN        NaN
# 1     SN2010ev        NaN           NaN        NaN        NaN        NaN
# 2    SN2016eja  17.206750  1.404774e-08  17.230560   0.000119  17.030989
# 3     SN2010jn  14.233835  6.861665e-09  14.193270   0.000175  14.088037
# 4  ASASSN-13ch  16.227730  1.687405e-08  16.275321   0.001099  16.193928
#
#    Kerr_UVW1        K_U    Kerr_U        K_B    Kerr_B        K_V    Kerr_V
# 0        NaN        NaN       NaN        NaN       NaN        NaN       NaN
# 1        NaN        NaN       NaN        NaN       NaN        NaN       NaN
# 2   0.001564  16.455300  0.002185  16.619328  0.000347  16.044343  0.016689
# 3   0.001423  13.770112  0.001559  13.744800  0.000775  13.321089  0.019150
# 4   0.000990  16.050746  0.000323  16.249731  0.000322  15.940390  0.008212
# (127, 13)

# %%
#unsupported operand type(s) for +: 'int' and 'NoneType means 
#unavailable redhift for that sn
